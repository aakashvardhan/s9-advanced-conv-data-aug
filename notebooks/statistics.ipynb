# %%
# !git clone 'https://github.com/aakashvardhan/s9-advanced-conv-data-aug.git'
# Out:
# Cloning into 's9-advanced-conv-data-aug'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 66 (delta 33), reused 51 (delta 18), pack-reused 0
# Receiving objects: 100% (66/66), 12.24 KiB | 6.12 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
import sys
sys.path.append('/content/s9-advanced-conv-data-aug')
sys.path.append('/content/s9-advanced-conv-data-aug/models')

# %%
import albumentations as A
import copy
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from albumentations.pytorch import ToTensorV2

# %%
def visualize_augmentations(dataset, idx=0, samples=10, cols=5):
    dataset = copy.deepcopy(dataset)
    dataset.transform = A.Compose([t for t in dataset.transform if not isinstance(t, (A.Normalize, ToTensorV2))])
    rows = samples // cols
    figure, ax = plt.subplots(nrows=rows, ncols=cols, figsize=(12, 6))
    for i in range(samples):
        image, _ = dataset[idx]
        ax.ravel()[i].imshow(image)
        ax.ravel()[i].set_axis_off()
    plt.tight_layout()
    plt.show()

# %%
from setup_cifar10_data import setup_cifar10
from config import get_config

# %%
config = get_config()
train_data,_ ,_, _ = setup_cifar10(config)
# Out:
# CUDA Available? False
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 28781162.62it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f73c3925ce23> in <cell line: 2>()
#       1 config = get_config()
# ----> 2 train_data,_ ,_, _ = setup_cifar10(config)
#
# /content/s9-advanced-conv-data-aug/setup_cifar10_data.py in setup_cifar10(config)
#      48     if cuda:
#      49         torch.cuda.manual_seed(1)
# ---> 50     train_data = CIFAR10Dataset(root='./data', train=True, download=True, transform="train")
#      51     test_data = CIFAR10Dataset(root='./data', train=False, download=True, transform="test")
#      52
#
# /content/s9-advanced-conv-data-aug/setup_cifar10_data.py in __init__(self, root, train, download, transform)
#      15                 A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=15, p=0.5),
#      16                 A.HorizontalFlip(p=0.5),
# ---> 17                 A.CoarseDropout(max_holes=1, max_height=16, max_width=16, min_holes=1, min_height=16, min_width=16, fill_value=(mean_value), p=0.75),
#      18                 A.Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.247, 0.243, 0.261)),
#      19                 ToTensorV2(),
#
# NameError: name 'mean_value' is not defined

# %%
random.seed(42)
visualize_augmentations(train_data)
